# %% [markdown]
# # ***S Guru Prasad***

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# Applying Bayesian Methods for Hackers styling to the notebook
plt.style.use("bmh")

# Reading the CSV File into a dataframe
df = pd.read_csv('datadoc.csv')

# %%
print(df)
print(df.head())      #displaying the first 5 rows of the dataframe
# Out:
#     Application No  HighSchool GPA  Physics Marks  Chem Marks  Biology Marks  \
# 0             1008             4.5             76          83             74
# 1             1010             3.3             67          74             65
# 2             1011             3.1             54          61             52
# 3             1015             4.1             76          83             74
# 4             1016             3.0             87          94             85
# ..             ...             ...            ...         ...            ...
# 61            1489             3.0             67          74             65
# 62            1489             2.9             78          85             76
# 63            1491             3.0             87          94             85
# 64            1495             4.5             65          72             63
# 65            1498             3.1             76          83             74
#
#     Unnamed: 5                   Name                Father Name          DOB  \
# 0          NaN  MUHAMMAD HAMZA NADEEM  MUHAMMAD NADEEM CHAUDHARY  22-Jun-1997
# 1          NaN      Hafiza Sana Habib            Habibullah Khan  25-Jan-1998
# 2          NaN            EZWA ASHFAQ             ASHFAQ HUSSAIN  18-Jan-1999
# 3          NaN      HINA AKRAM ABBASI      MUHAMMAD AKRAM ABBASI  19-Nov-1995
# 4          NaN      ROHA FARHAN LODHI          FARHAN KHAN LODHI  30-Mar-1998
# ..         ...                    ...                        ...          ...
# 61         NaN          FARHANA ISRAR                ISRAR AHMED   8-Dec-1996
# 62         NaN          FARHANA ISRAR                ISRAR AHMED   8-Dec-1996
# 63         NaN                  Urooj       Mukhtar Hussain Azad  18-Aug-1997
# 64         NaN            ABDUL WASAY              MANSOOR ANWER  17-Jun-1998
# 65         NaN      HAFIZA HAFSA EJAZ             EJAZ UR REHMAN  12-Apr-1997
#
#     SUM        AVG
# 0   233  77.666667
# 1   206  68.666667
# 2   167  55.666667
# 3   233  77.666667
# 4   266  88.666667
# ..  ...        ...
# 61  206  68.666667
# 62  239  79.666667
# 63  266  88.666667
# 64  200  66.666667
# 65  233  77.666667
#
# [66 rows x 11 columns]
#    Application No  HighSchool GPA  Physics Marks  Chem Marks  Biology Marks  \
# 0            1008             4.5             76          83             74
# 1            1010             3.3             67          74             65
# 2            1011             3.1             54          61             52
# 3            1015             4.1             76          83             74
# 4            1016             3.0             87          94             85
#
#    Unnamed: 5                   Name                Father Name          DOB  \
# 0         NaN  MUHAMMAD HAMZA NADEEM  MUHAMMAD NADEEM CHAUDHARY  22-Jun-1997
# 1         NaN      Hafiza Sana Habib            Habibullah Khan  25-Jan-1998
# 2         NaN            EZWA ASHFAQ             ASHFAQ HUSSAIN  18-Jan-1999
# 3         NaN      HINA AKRAM ABBASI      MUHAMMAD AKRAM ABBASI  19-Nov-1995
# 4         NaN      ROHA FARHAN LODHI          FARHAN KHAN LODHI  30-Mar-1998
#
#    SUM        AVG
# 0  233  77.666667
# 1  206  68.666667
# 2  167  55.666667
# 3  233  77.666667
# 4  266  88.666667

# %%
df.iloc[0:, 0:]       #displaying all rows and columns in tabular form
# Out:
#     Application No  HighSchool GPA  Physics Marks  Chem Marks  Biology Marks  \
# 0             1008             4.5             76          83             74
# 1             1010             3.3             67          74             65
# 2             1011             3.1             54          61             52
# 3             1015             4.1             76          83             74
# 4             1016             3.0             87          94             85
# ..             ...             ...            ...         ...            ...
# 61            1489             3.0             67          74             65
# 62            1489             2.9             78          85             76
# 63            1491             3.0             87          94             85
# 64            1495             4.5             65          72             63
# 65            1498             3.1             76          83             74
#
#     Unnamed: 5                   Name                Father Name          DOB  \
# 0          NaN  MUHAMMAD HAMZA NADEEM  MUHAMMAD NADEEM CHAUDHARY  22-Jun-1997
# 1          NaN      Hafiza Sana Habib            Habibullah Khan  25-Jan-1998
# 2          NaN            EZWA ASHFAQ             ASHFAQ HUSSAIN  18-Jan-1999
# 3          NaN      HINA AKRAM ABBASI      MUHAMMAD AKRAM ABBASI  19-Nov-1995
# 4          NaN      ROHA FARHAN LODHI          FARHAN KHAN LODHI  30-Mar-1998
# ..         ...                    ...                        ...          ...
# 61         NaN          FARHANA ISRAR                ISRAR AHMED   8-Dec-1996
# 62         NaN          FARHANA ISRAR                ISRAR AHMED   8-Dec-1996
# 63         NaN                  Urooj       Mukhtar Hussain Azad  18-Aug-1997
# 64         NaN            ABDUL WASAY              MANSOOR ANWER  17-Jun-1998
# 65         NaN      HAFIZA HAFSA EJAZ             EJAZ UR REHMAN  12-Apr-1997
#
#     SUM        AVG
# 0   233  77.666667
# 1   206  68.666667
# 2   167  55.666667
# 3   233  77.666667
# 4   266  88.666667
# ..  ...        ...
# 61  206  68.666667
# 62  239  79.666667
# 63  266  88.666667
# 64  200  66.666667
# 65  233  77.666667
#
# [66 rows x 11 columns]

# %%
df.describe()          #Genreal Description of the dataframe
df.info()              #Information about the dataframe
df.shape               #Shape of the dataframe(MNo of Rows,No of Columns)
print(df.columns,type(df.columns)) #Columns of the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Application No  66 non-null     int64
#  1   HighSchool GPA  66 non-null     float64
#  2   Physics Marks   66 non-null     int64
#  3   Chem Marks      66 non-null     int64
#  4   Biology Marks   66 non-null     int64
#  5   Unnamed: 5      0 non-null      float64
#  6   Name            66 non-null     object
#  7   Father Name     66 non-null     object
#  8   DOB             66 non-null     object
#  9   SUM             66 non-null     int64
#  10  AVG             66 non-null     float64
# dtypes: float64(3), int64(5), object(3)
# memory usage: 5.8+ KB
# Index(['Application No', 'HighSchool GPA', 'Physics Marks', 'Chem Marks',
#        'Biology Marks', 'Unnamed: 5', 'Name', 'Father Name', 'DOB', 'SUM',
#        'AVG'],
#       dtype='object') <class 'pandas.core.indexes.base.Index'>

# %%
df.index             #Index of the dataframe rows
# Out:
# RangeIndex(start=0, stop=66, step=1)

# %%
df.dtypes           #Returns the data type of each column
# Out:
# Application No      int64
# HighSchool GPA    float64
# Physics Marks       int64
# Chem Marks          int64
# Biology Marks       int64
# Unnamed: 5        float64
# Name               object
# Father Name        object
# DOB                object
# SUM                 int64
# AVG               float64
# dtype: object

# %%
df.values           #Returns list of all rows in the dataframe,Each Row is a list itself
# Out:
# array([[1008, 4.5, 76, 83, 74, nan, 'MUHAMMAD HAMZA NADEEM',
#         'MUHAMMAD NADEEM CHAUDHARY', '22-Jun-1997', 233, 77.66666667],
#        [1010, 3.3, 67, 74, 65, nan, 'Hafiza Sana Habib',
#         'Habibullah Khan', '25-Jan-1998', 206, 68.66666667],
#        [1011, 3.1, 54, 61, 52, nan, 'EZWA ASHFAQ', 'ASHFAQ HUSSAIN',
#         '18-Jan-1999', 167, 55.66666667],
#        [1015, 4.1, 76, 83, 74, nan, 'HINA AKRAM ABBASI',
#         'MUHAMMAD AKRAM ABBASI', '19-Nov-1995', 233, 77.66666667],
#        [1016, 3.0, 87, 94, 85, nan, 'ROHA FARHAN LODHI',
#         'FARHAN KHAN LODHI', '30-Mar-1998', 266, 88.66666667],
#        [1021, 4.5, 76, 83, 74, nan, 'SAIRA rAFIQ', 'MUHAMMAD RAFIQ',
#         '11-Nov-1998', 233, 77.66666667],
#        [1025, 4.1, 56, 63, 54, nan, 'HAFSA QAZI', 'SHAFI MOHAMMAD QAZI ',
#         '31-Jan-1999', 173, 57.66666667],
#        [1028, 3.3, 23, 30, 21, nan, 'TOOBA KHATOON',
#         'SHAIKH MUHAMMAD SHAKEEL', '5-May-1997', 74, 24.66666667],
#        [1029, 3.0, 67, 74, 65, nan, 'MUHAMMAD ANAS ALI RAZA',
#         'ASIF MEHMOOD', '17-Feb-1997', 206, 68.66666667],
#        [1032, 3.3, 54, 61, 52, nan, 'AYESHA', 'RASHID HUSSAIN SIDDIQUE',
#         '16-Mar-1998', 167, 55.66666667],
#        [1033, 4.5, 67, 74, 65, nan, 'SADIA ANWER', 'MUHAMMAD ANWER',
#         '3-Mar-1999', 206, 68.66666667],
#        [1036, 4.5, 78, 85, 76, nan, 'NABILA TOHEED', 'TOHEED AHMED',
#         '15-Dec-1998', 239, 79.66666667],
#        [1039, 2.4, 56, 63, 54, nan, 'FAIZA RUSTAM', 'SYED RUSTAM SHAH',
#         '10-Oct-1997', 173, 57.66666667],
#        [1047, 2.4, 39, 46, 37, nan, 'NEHA ARSHAD KHAN',
#         'ARSHAD MEHMOOD KHAN', '19-Oct-1998', 122, 40.66666667],
#        [1050, 3.2, 87, 94, 85, nan, 'SAIF ASLAM KHAN', 'ASLAM SHAKOOR',
#         '23-Feb-1997', 266, 88.66666667],
#        [1063, 4.1, 56, 63, 54, nan, 'TOOBA SANA', 'MUHAMMAD ZAHEER',
#         '1-Nov-1998', 173, 57.66666667],
#        [1067, 4.5, 54, 61, 52, nan, 'HAFSA', 'MUHAMMAD HANIF VOHRA',
#         '7-Jul-1998', 167, 55.66666667],
#        [1072, 3.0, 98, 105, 96, nan, 'PIRHA MASOOD',
#         'MASOOD AHMED SHAIKH', '17-Jan-1997', 299, 99.66666667],
#        [1080, 2.4, 56, 63, 54, nan, 'ANUM RAUF', 'QAZI ABDUL RAUF',
#         '10-Apr-1997', 173, 57.66666667],
#        [1082, 2.4, 33, 40, 31, nan, 'MUHAMMAD NASIR',
#         'MUHAMMAD IBRAHEEM', '23-Jan-1997', 104, 34.66666667],
#        [1087, 2.9, 67, 74, 65, nan, 'Muhammad Sami Qureshi',
#         'Shafi Muhammad Qureshi', '31-Jan-1999', 206, 68.66666667],
#        [1087, 3.1, 43, 50, 41, nan, 'Muhammad Sami Qureshi',
#         'Shafi Muhammad Qureshi', '31-Jan-1999', 134, 44.66666667],
#        [1088, 4.1, 76, 83, 74, nan, 'AREEBA MAHROOH GUL',
#         'AGHA MAJID GUL', '9-Feb-1997', 233, 77.66666667],
#        [1096, 2.9, 54, 61, 52, nan, 'Sumia', 'Abdul qudoos',
#         '1-Jan-1999', 167, 55.66666667],
#        [1117, 3.3, 54, 61, 52, nan, 'Roshan Kumar', 'Suresh',
#         '15-Jun-1998', 167, 55.66666667],
#        [1125, 2.9, 87, 94, 85, nan, 'JAVIRIYA ', 'MUHAMMAD IBRAHIM',
#         '3-Nov-1997', 266, 88.66666667],
#        [1152, 4.5, 33, 40, 31, nan, 'SARA AMJAD', 'ZAFAR IQBAL',
#         '21-Jan-1998', 104, 34.66666667],
#        [1257, 2.4, 67, 74, 65, nan, 'Urooj Shafqat',
#         'Shafqat Ur Rehman Sajid', '30-May-1997', 206, 68.66666667],
#        [1259, 3.2, 54, 61, 52, nan, 'TABINDA ZAIDI',
#         'SYED ARIF NADEEM ZAIDI', '3-Jun-1998', 167, 55.66666667],
#        [1263, 3.0, 54, 61, 52, nan, 'ARMISHA TARIQ', 'TARIQ RASHID',
#         '1-Aug-1999', 167, 55.66666667],
#        [1268, 3.1, 33, 40, 31, nan, 'Aleena Arshad', 'Arshad Ali',
#         '22-Jan-1999', 104, 34.66666667],
#        [1268, 3.2, 78, 85, 76, nan, 'Aleena Arshad', 'Arshad Ali',
#         '22-Jan-1999', 239, 79.66666667],
#        [1290, 2.4, 54, 61, 52, nan, 'SANAM SHAFI', 'SHAFI MUHAMMAD ',
#         '4-Nov-1997', 167, 55.66666667],
#        [1294, 4.1, 88, 95, 86, nan, 'MUHAMMAD ASHAR NAEEM',
#         'MUHAMMAD NAEEM ANWAR LATE', '20-Feb-1998', 269, 89.66666667],
#        [1294, 3.3, 78, 85, 76, nan, 'MUHAMMAD ASHAR NAEEM',
#         'MUHAMMAD NAEEM ANWAR LATE', '20-Feb-1998', 239, 79.66666667],
#        [1294, 3.1, 67, 74, 65, nan, 'MUHAMMAD ASHAR NAEEM',
#         'MUHAMMAD NAEEM ANWAR LATE', '20-Feb-1998', 206, 68.66666667],
#        [1296, 2.4, 88, 95, 86, nan, 'Ayesha Hassan', 'Muhammad Hassan',
#         '26-Aug-1999', 269, 89.66666667],
#        [1298, 2.9, 98, 105, 96, nan, 'Ammar khan soomro', 'Abdul jabbar',
#         '16-Mar-2000', 299, 99.66666667],
#        [1354, 4.1, 43, 50, 41, nan, 'MAHAM', 'MUHAMMAD SIDDIQUE',
#         '23-Aug-1996', 134, 44.66666667],
#        [1354, 4.1, 78, 85, 76, nan, 'MAHAM', 'MUHAMMAD SIDDIQUE',
#         '23-Aug-1996', 239, 79.66666667],
#        [1354, 3.3, 98, 105, 96, nan, 'MAHAM', 'MUHAMMAD SIDDIQUE',
#         '23-Aug-1996', 299, 99.66666667],
#        [1354, 3.1, 88, 95, 86, nan, 'MAHAM', 'MUHAMMAD SIDDIQUE',
#         '23-Aug-1996', 269, 89.66666667],
#        [1354, 3.2, 87, 94, 85, nan, 'MAHAM', 'MUHAMMAD SIDDIQUE',
#         '23-Aug-1996', 266, 88.66666667],
#        [1354, 4.5, 56, 63, 54, nan, 'MAHAM', 'MUHAMMAD SIDDIQUE',
#         '23-Aug-1996', 173, 57.66666667],
#        [1354, 3.0, 45, 52, 43, nan, 'MAHAM', 'MUHAMMAD SIDDIQUE',
#         '23-Aug-1996', 140, 46.66666667],
#        [1366, 3.3, 87, 94, 85, nan, 'AYISHA', 'KAMAL IFTIKHAR AHMED',
#         '3-Apr-1998', 266, 88.66666667],
#        [1366, 3.1, 56, 63, 54, nan, 'AYISHA', 'KAMAL IFTIKHAR AHMED',
#         '3-Apr-1998', 173, 57.66666667],
#        [1366, 3.2, 67, 74, 65, nan, 'AYISHA', 'KAMAL IFTIKHAR AHMED',
#         '3-Apr-1998', 206, 68.66666667],
#        [1408, 4.5, 39, 46, 37, nan, 'MARYAM MANSOOR',
#         'MANSOOR AHMED ANSARI', '1-Aug-1997', 122, 40.66666667],
#        [1409, 3.0, 87, 94, 85, nan, 'SAFFA MARIAM', 'MUHUMMAD SALEEM',
#         '7-Sep-1995', 266, 88.66666667],
#        [1418, 3.1, 78, 85, 76, nan, 'PREETI AdVANI',
#         'JAWAHAR LAL ADVANI', '8-Aug-1998', 239, 79.66666667],
#        [1420, 2.9, 23, 30, 21, nan, 'VERKHA TANWANI', 'KANYA LAL',
#         '17-Jul-1998', 74, 24.66666667],
#        [1464, 3.0, 65, 72, 63, nan, 'Aaiman Shahid', 'Shahid Ahmed',
#         '12-Jan-1997', 200, 66.66666667],
#        [1467, 2.9, 87, 94, 85, nan, 'IQRA ASLAM', 'Muhammad Aslam',
#         '15-Aug-1997', 266, 88.66666667],
#        [1467, 3.2, 45, 52, 43, nan, 'IQRA ASLAM', 'Muhammad Aslam',
#         '15-Aug-1997', 140, 46.66666667],
#        [1472, 4.1, 65, 72, 63, nan, 'RABIYA MAZHAR', 'MAZHAR JAWED',
#         '26-Sep-1999', 200, 66.66666667],
#        [1472, 3.3, 45, 52, 43, nan, 'RABIYA MAZHAR', 'MAZHAR JAWED',
#         '26-Sep-1999', 140, 46.66666667],
#        [1480, 2.9, 33, 40, 31, nan, 'WARDHA', 'ATTAULLAH KHAN',
#         '29-Mar-1996', 104, 34.66666667],
#        [1486, 3.2, 33, 40, 31, nan, 'MUHAMMAD ISMAIL', 'ABDUL LATIF',
#         '23-May-1988', 104, 34.66666667],
#        [1489, 2.4, 54, 61, 52, nan, 'FARHANA ISRAR', 'ISRAR AHMED',
#         '8-Dec-1996', 167, 55.66666667],
#        [1489, 3.2, 65, 72, 63, nan, 'FARHANA ISRAR', 'ISRAR AHMED',
#         '8-Dec-1996', 200, 66.66666667],
#        [1489, 3.0, 67, 74, 65, nan, 'FARHANA ISRAR', 'ISRAR AHMED',
#         '8-Dec-1996', 206, 68.66666667],
#        [1489, 2.9, 78, 85, 76, nan, 'FARHANA ISRAR', 'ISRAR AHMED',
#         '8-Dec-1996', 239, 79.66666667],
#        [1491, 3.0, 87, 94, 85, nan, 'Urooj', 'Mukhtar Hussain Azad',
#         '18-Aug-1997', 266, 88.66666667],
#        [1495, 4.5, 65, 72, 63, nan, 'ABDUL WASAY', 'MANSOOR ANWER',
#         '17-Jun-1998', 200, 66.66666667],
#        [1498, 3.1, 76, 83, 74, nan, 'HAFIZA HAFSA EJAZ',
#         'EJAZ UR REHMAN', '12-Apr-1997', 233, 77.66666667]], dtype=object)

# %%
P=df["Physics Marks"]   #Reading Physics Marks as Array
C=df["Chem Marks"]
B=df["Biology Marks"]
Overall_Avg=df["AVG"]
Sum=df["SUM"]
Avg=df["AVG"]        #Reading average of all 3 subjects as an Array
GPA=df["HighSchool GPA"] #Reading GPA of a Studenty as an Array
print(P)
print(type(P))       #Type of P is a pandas.series
print(C)
print(B)
print(Sum)
print(Avg)
print(GPA)

Phy_Avg=P.mean()
Chem_Avg=C.mean()
Bio_Avg=B.mean()
Overall_Avg=Avg.mean()

print("Phy_Avg",Phy_Avg)
print("Chem_Avg",Chem_Avg)
print("Bio_Avg",Bio_Avg)
print("Overall_Avg",Overall_Avg)
# Out:
# 0     76
# 1     67
# 2     54
# 3     76
# 4     87
#       ..
# 61    67
# 62    78
# 63    87
# 64    65
# 65    76
# Name: Physics Marks, Length: 66, dtype: int64
# <class 'pandas.core.series.Series'>
# 0     83
# 1     74
# 2     61
# 3     83
# 4     94
#       ..
# 61    74
# 62    85
# 63    94
# 64    72
# 65    83
# Name: Chem Marks, Length: 66, dtype: int64
# 0     74
# 1     65
# 2     52
# 3     74
# 4     85
#       ..
# 61    65
# 62    76
# 63    85
# 64    63
# 65    74
# Name: Biology Marks, Length: 66, dtype: int64
# 0     233
# 1     206
# 2     167
# 3     233
# 4     266
#      ...
# 61    206
# 62    239
# 63    266
# 64    200
# 65    233
# Name: SUM, Length: 66, dtype: int64
# 0     77.666667
# 1     68.666667
# 2     55.666667
# 3     77.666667
# 4     88.666667
#         ...
# 61    68.666667
# 62    79.666667
# 63    88.666667
# 64    66.666667
# 65    77.666667
# Name: AVG, Length: 66, dtype: float64
# 0     4.5
# 1     3.3
# 2     3.1
# 3     4.1
# 4     3.0
#      ...
# 61    3.0
# 62    2.9
# 63    3.0
# 64    4.5
# 65    3.1
# Name: HighSchool GPA, Length: 66, dtype: float64
# Phy_Avg 64.0909090909091
# Chem_Avg 71.0909090909091
# Bio_Avg 62.09090909090909
# Overall_Avg 65.75757576090909

# %%
plt.style.use("bmh")

l=[Phy_Avg,Chem_Avg,Bio_Avg,Overall_Avg]

plt.xlabel('Subjects')
plt.ylabel('Averages')
plt.bar(["Physics","Chemistry","Biology","Overall"],l)
plt.show()

# INFERENCE
# Chemistry is Easy 
# Biology is the Hardest
# Students perform below Average in Physics and Biology
# Students Scores Above Average in Chemistry

# %%
import scipy
from scipy import stats  #Applying Linear Regression to find Total using Physics Score 

my_y = Sum
my_x = P

slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(my_x, my_y)
    
print(slope)
print(intercept)

plt.xlabel('Physics Marks')
plt.ylabel('Total Marks')
plt.scatter(P,Sum)
plt.show()

def calc_total_with_phy_score():
    print("Enter Score")
    n=int(input())
    ans=(n*slope)+intercept
    print(ans)
calc_total_with_phy_score()

# INFERENCE
# There is a linear relationship between Physics and Total Marks
# Students who score well in genreal perform well in Physics and vice versa
# Out:
# 2.9999999999999964
# 5.000000000000227
# Enter Score
# 229.99999999999997

# %%
import datetime 
Application_no=df["Application No"]
print(Application_no)
DOB=df["DOB"]
print(DOB)
print(type(DOB[0]))
def get_month_no(mon):
    if(mon=="Jan"):
      return 1
    if(mon=="Feb"):
      return 2
    if(mon=="Mar"):
      return 3
    if(mon=="Apr"):
      return 4
    if(mon=="May"):
      return 5
    if(mon=="Jun"):
      return 6
    if(mon=="Jul"):
      return 7
    if(mon=="Aug"):
      return 8
    if(mon=="Sep"):
      return 9
    if(mon=="Oct"):
      return 10
    if(mon=="Nov"):
      return 11
    if(mon=="Dec"):
      return 12
k=DOB[10]
print(k)
print(k[-4:])
print(len(k))
print(k[-4:0])
# Out:
# 0     1008
# 1     1010
# 2     1011
# 3     1015
# 4     1016
#       ...
# 61    1489
# 62    1489
# 63    1491
# 64    1495
# 65    1498
# Name: Application No, Length: 66, dtype: int64
# 0     22-Jun-1997
# 1     25-Jan-1998
# 2     18-Jan-1999
# 3     19-Nov-1995
# 4     30-Mar-1998
#          ...
# 61     8-Dec-1996
# 62     8-Dec-1996
# 63    18-Aug-1997
# 64    17-Jun-1998
# 65    12-Apr-1997
# Name: DOB, Length: 66, dtype: object
# <class 'str'>
# 3-Mar-1999
# 1999
# 10

# %%
Bday=[]                   #Converting String to Datetime
for x in DOB:
    dd=mm=yyyy=flag=0
    if(x[1]=="-"):
      dd=int(x[0])
      flag=0
    else:
      dd=int(x[0:2])
      flag=1
    yyyy=x[-4:]
    yyyy=int(yyyy)
    if(flag==0):
      mm=get_month_no(x[2:-5])
    else:
      mm=get_month_no(x[3:-5])
    elem=datetime.datetime(yyyy,mm,dd)
    Bday.append(elem)
print(Bday)
print(type(Bday[12]))
print(Bday[0].year)
# From Bday get list of all the years
# Out:
# [datetime.datetime(1997, 6, 22, 0, 0), datetime.datetime(1998, 1, 25, 0, 0), datetime.datetime(1999, 1, 18, 0, 0), datetime.datetime(1995, 11, 19, 0, 0), datetime.datetime(1998, 3, 30, 0, 0), datetime.datetime(1998, 11, 11, 0, 0), datetime.datetime(1999, 1, 31, 0, 0), datetime.datetime(1997, 5, 5, 0, 0), datetime.datetime(1997, 2, 17, 0, 0), datetime.datetime(1998, 3, 16, 0, 0), datetime.datetime(1999, 3, 3, 0, 0), datetime.datetime(1998, 12, 15, 0, 0), datetime.datetime(1997, 10, 10, 0, 0), datetime.datetime(1998, 10, 19, 0, 0), datetime.datetime(1997, 2, 23, 0, 0), datetime.datetime(1998, 11, 1, 0, 0), datetime.datetime(1998, 7, 7, 0, 0), datetime.datetime(1997, 1, 17, 0, 0), datetime.datetime(1997, 4, 10, 0, 0), datetime.datetime(1997, 1, 23, 0, 0), datetime.datetime(1999, 1, 31, 0, 0), datetime.datetime(1999, 1, 31, 0, 0), datetime.datetime(1997, 2, 9, 0, 0), datetime.datetime(1999, 1, 1, 0, 0), datetime.datetime(1998, 6, 15, 0, 0), datetime.datetime(1997, 11, 3, 0, 0), datetime.datetime(1998, 1, 21, 0, 0), datetime.datetime(1997, 5, 30, 0, 0), datetime.datetime(1998, 6, 3, 0, 0), datetime.datetime(1999, 8, 1, 0, 0), datetime.datetime(1999, 1, 22, 0, 0), datetime.datetime(1999, 1, 22, 0, 0), datetime.datetime(1997, 11, 4, 0, 0), datetime.datetime(1998, 2, 20, 0, 0), datetime.datetime(1998, 2, 20, 0, 0), datetime.datetime(1998, 2, 20, 0, 0), datetime.datetime(1999, 8, 26, 0, 0), datetime.datetime(2000, 3, 16, 0, 0), datetime.datetime(1996, 8, 23, 0, 0), datetime.datetime(1996, 8, 23, 0, 0), datetime.datetime(1996, 8, 23, 0, 0), datetime.datetime(1996, 8, 23, 0, 0), datetime.datetime(1996, 8, 23, 0, 0), datetime.datetime(1996, 8, 23, 0, 0), datetime.datetime(1996, 8, 23, 0, 0), datetime.datetime(1998, 4, 3, 0, 0), datetime.datetime(1998, 4, 3, 0, 0), datetime.datetime(1998, 4, 3, 0, 0), datetime.datetime(1997, 8, 1, 0, 0), datetime.datetime(1995, 9, 7, 0, 0), datetime.datetime(1998, 8, 8, 0, 0), datetime.datetime(1998, 7, 17, 0, 0), datetime.datetime(1997, 1, 12, 0, 0), datetime.datetime(1997, 8, 15, 0, 0), datetime.datetime(1997, 8, 15, 0, 0), datetime.datetime(1999, 9, 26, 0, 0), datetime.datetime(1999, 9, 26, 0, 0), datetime.datetime(1996, 3, 29, 0, 0), datetime.datetime(1988, 5, 23, 0, 0), datetime.datetime(1996, 12, 8, 0, 0), datetime.datetime(1996, 12, 8, 0, 0), datetime.datetime(1996, 12, 8, 0, 0), datetime.datetime(1996, 12, 8, 0, 0), datetime.datetime(1997, 8, 18, 0, 0), datetime.datetime(1998, 6, 17, 0, 0), datetime.datetime(1997, 4, 12, 0, 0)]
# <class 'datetime.datetime'>
# 1997

# %%
# Genreal PIE Chart syntax 
plt.style.use("bmh")
Year=[]
for x in Bday:
    Year.append(x.year)
print(Year)
print(type(Year[0]))
print(Year[0])
# Get unique year values and store it in a list called labels and sort it in ascending order
labels=[]
for x in Year:
    if(x not in labels):
      labels.append(x)
labels.sort()
print(labels)
# Get the count of each unique year and store it in a list called sizes
sizes=[]
for x in labels:
    count=0
    for y in Year:
        if(x==y):
            count+=1
    sizes.append(count)
print(sizes)
# Plot the pie chart using labels and sizes list and display the percentage of each year
plt.figure(figsize=(20,20))
plt.pie(sizes,labels=labels,autopct='%1.1f%%',startangle=90)
plt.axis('equal')
plt.show()
# INFERENCE
# Most of the students are born in 1998
# More than 90 percent of students are born between 1996 and 1999
# Out:
# [1997, 1998, 1999, 1995, 1998, 1998, 1999, 1997, 1997, 1998, 1999, 1998, 1997, 1998, 1997, 1998, 1998, 1997, 1997, 1997, 1999, 1999, 1997, 1999, 1998, 1997, 1998, 1997, 1998, 1999, 1999, 1999, 1997, 1998, 1998, 1998, 1999, 2000, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1998, 1998, 1998, 1997, 1995, 1998, 1998, 1997, 1997, 1997, 1999, 1999, 1996, 1988, 1996, 1996, 1996, 1996, 1997, 1998, 1997]
# <class 'int'>
# 1997
# [1988, 1995, 1996, 1997, 1998, 1999, 2000]
# [1, 2, 12, 18, 20, 12, 1]

# %%
from scipy.stats import pearsonr   
print(pearsonr(P,C))     #Finding Correlation Coefficient
#INFERENCE
#Have very Strong Linear RelationShip
# Out:
# PearsonRResult(statistic=1.0, pvalue=0.0)

# %%
print(pearsonr(Avg,GPA)) 
plt.scatter(Avg,GPA)
#INFERENCE
# Very WeaK Linear RelationShip bw GPA and Avg
#No Linear Relation between Age and GPA/Avg/Marks of any subject
# Out:
# PearsonRResult(statistic=0.016678101674156176, pvalue=0.8942614610645303)

# %%
year=[]                       #Distribution Based on Birth Year
for x in Bday:
  year.append(x.year)
d={}
for x in year:
  if x not in d.keys():
    d[x]=1
  else:
    d[x]=d[x]+1
print(d)
years=list(d.keys())
count=list(d.values())
plt.bar(years,count)
plt.show()
#INFERENCE
#Time period between 1997 and 1999 has seen the most no of Students
# Out:
# {1997: 18, 1998: 20, 1999: 12, 1995: 2, 2000: 1, 1996: 12, 1988: 1}

# %% [markdown]
# DATA VISUALISATIONS

# %%
import pandas as panda
raw_data=panda.read_csv("datadoc.csv")
raw_data.describe()

clean1=raw_data[raw_data["Chem Marks"]<=100]
clean2=clean1[clean1["Physics Marks"]<=100]
cleaned=clean2[clean2["Biology Marks"]<=100]
cleaned.describe()
# cleaned.corr()

import matplotlib.pyplot as ppp
gpa=cleaned['HighSchool GPA']
chem=cleaned['Chem Marks']
phy=cleaned['Physics Marks']
bio=cleaned['Biology Marks']

overall=phy+chem+bio
count=0

phytotal=0
count=0
for x in phy:
  phytotal=phytotal+x
  count=count+1
phyavg=phytotal/count

chemtotal=0
for x in chem:
  chemtotal=chemtotal+x
chemavg=chemtotal/count

biototal=0
for x in bio:
  biototal=biototal+x
bioavg=biototal/count

overtotal=0
for x in overall:
  overtotal=overtotal+x
overtotavg=overall/3
overavg=overtotal/(3*count)

# %%
ppp.scatter(gpa,phy)
ppp.title("GPA vs Physics Marks")
ppp.xlabel("GPA")
ppp.ylabel("Physics Marks")
# Out:
# Text(0, 0.5, 'Physics Marks')

# %%
ppp.scatter(gpa,bio)
ppp.title("GPA vs Biology marks")
ppp.xlabel("GPA")
ppp.ylabel("Biology Marks")
# Out:
# Text(0, 0.5, 'Biology Marks')

# %%
ppp.scatter(gpa,chem)
ppp.title("GPA vs Chem marks")
ppp.xlabel("GPA")
ppp.ylabel("Chem Marks")
# Out:
# Text(0, 0.5, 'Chem Marks')

# %%
ppp.scatter(phy,chem)
ppp.title("Physics marks vs Chem marks")
ppp.xlabel("Physics Marks")
ppp.ylabel("Chem Marks")
# Out:
# Text(0, 0.5, 'Chem Marks')

# %%
ppp.scatter(bio,chem)
ppp.title("Biology marks vs Chem marks")
ppp.xlabel("Biology Marks")
ppp.ylabel("Chem Marks")
# Out:
# Text(0, 0.5, 'Chem Marks')
